# %%
import os 
try:
    GOOGLE_API_KEY = "AIzaSyAZQCA-ozuBD9qV6tAk577W_Q-A3U5cYew"
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("GOOGLE_API_KEY set successfully.")
except Exception as e:
    print(f"Error setting GOOGLE_API_KEY: {e}")
# Out:
# GOOGLE_API_KEY set successfully.

# %%
from typing import Any, Dict

from google.adk.agents import Agent, LlmAgent
from google.adk.apps.app import App, EventsCompactionConfig
from google.adk.models.google_llm import Gemini
from google.adk.sessions import DatabaseSessionService
from google.adk.sessions import InMemorySessionService
from google.adk.runners import Runner
from google.adk.tools.tool_context import ToolContext
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
class Movie:
    def __init__(self,title,year,imdb_score,have_seen):  #these are the variables the class takes 
        self.title = title
        self.year = year
        self.imdb_score = imdb_score
        self.have_seen = have_seen
    
    def nice_print(self): #these are the functions the class takes
        print("Title: ", self.title)
        print("Year of production: ", self.year)
        print("IMDB Score: ", self.imdb_score)
        print("I have seen it: ", self.have_seen)
        
Movie.title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 14
#      11         print("IMDB Score: ", self.imdb_score)
#      12         print("I have seen it: ", self.have_seen)
# ---> 14 Movie.title
#
# AttributeError: type object 'Movie' has no attribute 'title'
